# %%
from spam import *

column_names = load_column_names("./spam/spambase.names")
data = load_data("./spam/spambase.data", column_names)

# %%
ind = list(data.columns[:-1].values)

# %%
dep = [data.columns[-1]]

# %%
network1 = Network(data, ind, dep, [5,5,1])
network1.train_network(1000, 0.01)

# %%
res1 = network1.test("spam-class-2Hidd_5_5Neur-1000_001","spam-class_5_5_1000_001",binary=True)
# Out:
# c:\Users\gabri\OneDrive\Documents\VMBoxShared\sep_dic_2023\IA\proyecto_2\CI5438-Proyecto2\network.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %%
network2 = Network(data, ind, dep, [5,1])
network2.train_network(1000, 0.01)

# %%
res2 = network2.test("spam-class-1hidden-5Neur-001LR","spam-class_5_1000_001",binary=True)
# Out:
# c:\Users\gabri\OneDrive\Documents\VMBoxShared\sep_dic_2023\IA\proyecto_2\CI5438-Proyecto2\network.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %%
network3 = Network(data, ind, dep, [5,5,1])
network3.train_network(1000, 0.1)

# %%
res3 = network3.test("spam-class-1hidden-5Neur-01LR","spam-class_5_1000_01",binary=True)
# Out:
# c:\Users\gabri\OneDrive\Documents\VMBoxShared\sep_dic_2023\IA\proyecto_2\CI5438-Proyecto2\network.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %%
network4 = Network(data, ind, dep, [1])
network4.train_network(1000, 0.1)

# %%
res4 = network4.test("spam-class-1Neur","spam-class_uni_1000_01",binary=True)
# Out:
# c:\Users\gabri\OneDrive\Documents\VMBoxShared\sep_dic_2023\IA\proyecto_2\CI5438-Proyecto2\network.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %%
network5 = Network(data, ind, dep, [5,5,1])
network5.train_network(1000, 0.1)

# %%
res5 = network5.test("spam-class-2Hidd_5_5Neur-1000_01","spam-class_5_5_1000_01",binary=True)
# Out:
# c:\Users\gabri\OneDrive\Documents\VMBoxShared\sep_dic_2023\IA\proyecto_2\CI5438-Proyecto2\network.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %%
df_spam = res1.copy()

# %%
for df in [res2,res3,res4,res5]:
    df_spam = df_spam.append(df)
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_6280\3463649860.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_spam = df_spam.append(df)
# C:\Users\gabri\AppData\Local\Temp\ipykernel_6280\3463649860.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_spam = df_spam.append(df)
# C:\Users\gabri\AppData\Local\Temp\ipykernel_6280\3463649860.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_spam = df_spam.append(df)
